# %% [markdown]
# See https://github.com/csianglim/weather-gc-ca-python/blob/master/Part%20I%20-%20Data%20Extraction%20and%20Cleaning.ipynb for a demo on how to download weather data

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil import rrule
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import requests
import re

# %%
# Call Environment Canada API
# Returns a dataframe of data
def getHourlyData(stationID, year, month):
    base_url = "http://climate.weather.gc.ca/climate_data/bulk_data_e.html?"
    query_url = "format=csv&stationID={}&Year={}&Month={}&timeframe=1".format(stationID, year, month)
    api_endpoint = base_url + query_url
    return pd.read_csv(api_endpoint, skiprows=15)

# %%
# Download Vancouver weather data
stationID = 888
start_date = datetime.strptime('Jan2015', '%b%Y')
end_date = datetime.strptime('Dec2019', '%b%Y')

frames = []
for dt in rrule.rrule(rrule.MONTHLY, dtstart=start_date, until=end_date):
    df = getHourlyData(stationID, dt.year, dt.month)
    frames.append(df)

weather_data_vancouver = pd.concat(frames)
weather_data_vancouver['Date/Time'] = pd.to_datetime(weather_data_vancouver['Date/Time'])
weather_data_vancouver['Temp (°C)'] = pd.to_numeric(weather_data_vancouver['Temp (°C)'])
weather_data_vancouver['Station ID'] = stationID
weather_data_vancouver['Station Name'] = "VANCOUVER HARBOUR CS"

# %%
weather_data_vancouver.head()
# Out:
#             Date/Time  Year  Month  Day   Time  Temp (°C)  Temp Flag  \
# 0 2015-06-01 00:00:00  2015      6    1  00:00       16.4        NaN
# 1 2015-06-01 01:00:00  2015      6    1  01:00       16.9        NaN
# 2 2015-06-01 02:00:00  2015      6    1  02:00       16.2        NaN
# 3 2015-06-01 03:00:00  2015      6    1  03:00       16.2        NaN
# 4 2015-06-01 04:00:00  2015      6    1  04:00       14.9        NaN
#
#    Dew Point Temp (°C)  Dew Point Temp Flag  Rel Hum (%)  \
# 0                 12.6                  NaN         78.0
# 1                 12.5                  NaN         75.0
# 2                 11.7                  NaN         75.0
# 3                 13.2                  NaN         82.0
# 4                 11.7                  NaN         81.0
#
#            ...           Visibility Flag  Stn Press (kPa) Stn Press Flag  \
# 0          ...                       NaN              NaN              M
# 1          ...                       NaN              NaN              M
# 2          ...                       NaN              NaN              M
# 3          ...                       NaN              NaN              M
# 4          ...                       NaN              NaN              M
#
#    Hmdx Hmdx Flag  Wind Chill  Wind Chill Flag  Weather Station ID  \
# 0   NaN       NaN         NaN              NaN      NaN        888
# 1   NaN       NaN         NaN              NaN      NaN        888
# 2   NaN       NaN         NaN              NaN      NaN        888
# 3   NaN       NaN         NaN              NaN      NaN        888
# 4   NaN       NaN         NaN              NaN      NaN        888
#
#            Station Name
# 0  VANCOUVER HARBOUR CS
# 1  VANCOUVER HARBOUR CS
# 2  VANCOUVER HARBOUR CS
# 3  VANCOUVER HARBOUR CS
# 4  VANCOUVER HARBOUR CS
#
# [5 rows x 26 columns]

# %%
# Download Toronto weather data
stationID = 48549
start_date = datetime.strptime('Jan2015', '%b%Y')
end_date = datetime.strptime('Dec2019', '%b%Y')

frames = []
for dt in rrule.rrule(rrule.MONTHLY, dtstart=start_date, until=end_date):
    df = getHourlyData(stationID, dt.year, dt.month)
    frames.append(df)

weather_data_toronto = pd.concat(frames)
weather_data_toronto['Date/Time'] = pd.to_datetime(weather_data_toronto['Date/Time'])
weather_data_toronto['Temp (°C)'] = pd.to_numeric(weather_data_toronto['Temp (°C)'])
weather_data_toronto['Station ID'] = stationID
weather_data_toronto['Station Name'] = "TORONTO CITY CENTRE"

# %%
weather_data_toronto.head()
# Out:
#             Date/Time  Year  Month  Day   Time  Temp (°C) Temp Flag  \
# 0 2015-01-01 00:00:00  2015      1    1  00:00       -6.2       NaN
# 1 2015-01-01 01:00:00  2015      1    1  01:00       -6.0       NaN
# 2 2015-01-01 02:00:00  2015      1    1  02:00       -6.2       NaN
# 3 2015-01-01 03:00:00  2015      1    1  03:00       -6.0       NaN
# 4 2015-01-01 04:00:00  2015      1    1  04:00       -6.0       NaN
#
#    Dew Point Temp (°C) Dew Point Temp Flag  Rel Hum (%)         ...           \
# 0                -13.2                 NaN         58.0         ...
# 1                -13.7                 NaN         55.0         ...
# 2                -13.3                 NaN         57.0         ...
# 3                -12.0                 NaN         63.0         ...
# 4                -12.2                 NaN         62.0         ...
#
#   Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx Hmdx Flag  Wind Chill  \
# 0             NaN           100.68            NaN   NaN       NaN       -16.0
# 1             NaN           100.59            NaN   NaN       NaN       -16.0
# 2             NaN           100.56            NaN   NaN       NaN       -16.0
# 3             NaN           100.58            NaN   NaN       NaN       -15.0
# 4             NaN           100.50            NaN   NaN       NaN       -15.0
#
#   Wind Chill Flag  Weather Station ID         Station Name
# 0             NaN      NaN      48549  TORONTO CITY CENTRE
# 1             NaN      NaN      48549  TORONTO CITY CENTRE
# 2             NaN      NaN      48549  TORONTO CITY CENTRE
# 3             NaN      NaN      48549  TORONTO CITY CENTRE
# 4             NaN      NaN      48549  TORONTO CITY CENTRE
#
# [5 rows x 26 columns]

# %%
# append the two data sets together
weather_data = pd.concat([weather_data_vancouver, weather_data_toronto])

# %%
weather_data.head()
# Out:
#             Date/Time  Year  Month  Day   Time  Temp (°C) Temp Flag  \
# 0 2015-01-01 00:00:00  2015      1    1  00:00        0.2       NaN
# 1 2015-01-01 01:00:00  2015      1    1  01:00        0.1       NaN
# 2 2015-01-01 02:00:00  2015      1    1  02:00       -1.3       NaN
# 3 2015-01-01 03:00:00  2015      1    1  03:00       -0.5       NaN
# 4 2015-01-01 04:00:00  2015      1    1  04:00       -0.4       NaN
#
#    Dew Point Temp (°C) Dew Point Temp Flag  Rel Hum (%)          ...           \
# 0                 -1.8                 NaN         86.0          ...
# 1                 -1.8                 NaN         87.0          ...
# 2                 -2.9                 NaN         89.0          ...
# 3                 -2.2                 NaN         89.0          ...
# 4                 -1.6                 NaN         92.0          ...
#
#   Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx Hmdx Flag  Wind Chill  \
# 0             NaN              NaN              M   NaN       NaN         NaN
# 1             NaN              NaN              M   NaN       NaN         NaN
# 2             NaN              NaN              M   NaN       NaN         NaN
# 3             NaN              NaN              M   NaN       NaN         NaN
# 4             NaN              NaN              M   NaN       NaN         NaN
#
#   Wind Chill Flag  Weather Station ID          Station Name
# 0             NaN      NaN        888  VANCOUVER HARBOUR CS
# 1             NaN      NaN        888  VANCOUVER HARBOUR CS
# 2             NaN      NaN        888  VANCOUVER HARBOUR CS
# 3             NaN      NaN        888  VANCOUVER HARBOUR CS
# 4             NaN      NaN        888  VANCOUVER HARBOUR CS
#
# [5 rows x 26 columns]

# %%
import OS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-4447e580a96f> in <module>
# ----> 1 import OS
#
# ModuleNotFoundError: No module named 'OS'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Downloading Vancouver Weather Data.ipynb',
#  'Part I - Data Extraction and Cleaning.ipynb']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sedwardes\\Documents\\GitHub\\Vancouver Weather\\notebooks'

# %%
os.listdir("")
